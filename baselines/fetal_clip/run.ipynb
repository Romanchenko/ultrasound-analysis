# %%
# %pip install open_clip_torch torchmetrics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 16.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torchmetrics] [torchmetrics]
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from run import main
# Out:
# cpu

# %%
main("/home/jupyter/datasphere/project/ultrasound/models/FetalCLIP_weights.pt")
# Out:
# /home/jupyter/work/resources/ultrasound/ultrasound-analysis/baselines/fetal_clip/run.py:154: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# /home/jupyter/.local/lib/python3.10/site-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]/home/jupyter/work/resources/ultrasound/ultrasound-analysis/baselines/fetal_clip/run.py:170: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# /home/jupyter/.local/lib/python3.10/site-packages/torch/amp/autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# ...
