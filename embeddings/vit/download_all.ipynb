# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/SHAD/project
# Out:
# '19.01-30.01 Пытаемся выровнять датасеты.gslides'
#  checkpoints
#  Data.rar
#  fetal_head_circumference
#  fetal_planes_db
#  FETAL_PLANES_ZENODO.zip
# 'Physically-informed Self-Supervised Learning for Ultrasound Image Analysis.gslides'
# 'Project Timeline.gsheet'
# 'Оцениваем результаты выравнивания.gslides'
# 'Часть 2 Physically-informed Self-Supervised Learning for Ultrasound Image Analysis.gslides'

# %%
# !wget https://zenodo.org/records/1322001/files/test_set_pixel_size.csv -O /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set_pixel_size.csv
# Out:
# --2026-03-23 17:49:55--  https://zenodo.org/records/1322001/files/test_set_pixel_size.csv
# Resolving zenodo.org (zenodo.org)... 188.185.48.75, 188.184.103.118, 188.184.98.114, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9051 (8.8K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set_pixel_size.csv’
#
# /content/drive/MyDr 100%[===================>]   8.84K  --.-KB/s    in 0.01s
#
# 2026-03-23 17:49:56 (600 KB/s) - ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set_pixel_size.csv’ saved [9051/9051]

# %%
# !wget https://zenodo.org/records/1322001/files/training_set_pixel_size_and_HC.csv -O /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set_pixel_size_and_HC.csv
# Out:
# --2026-03-23 17:50:39--  https://zenodo.org/records/1322001/files/training_set_pixel_size_and_HC.csv
# Resolving zenodo.org (zenodo.org)... 188.184.103.118, 188.185.43.153, 137.138.153.219, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33603 (33K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set_pixel_size_and_HC.csv’
#
# /content/drive/MyDr 100%[===================>]  32.82K  --.-KB/s    in 0.03s
#
# 2026-03-23 17:50:39 (1.00 MB/s) - ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set_pixel_size_and_HC.csv’ saved [33603/33603]

# %%
# !wget https://zenodo.org/records/1322001/files/test_set.zip -O /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set.zip
# Out:
# --2026-03-23 17:51:03--  https://zenodo.org/records/1322001/files/test_set.zip
# Resolving zenodo.org (zenodo.org)... 188.184.103.118, 188.185.43.153, 137.138.153.219, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.118|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43751086 (42M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set.zip’
#
# /content/drive/MyDr 100%[===================>]  41.72M  56.4MB/s    in 0.7s
#
# 2026-03-23 17:51:04 (56.4 MB/s) - ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set.zip’ saved [43751086/43751086]

# %%
# !wget https://zenodo.org/records/1322001/files/training_set.zip -O /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set.zip
# Out:
# --2026-03-23 17:51:34--  https://zenodo.org/records/1322001/files/training_set.zip
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.184.98.114, 137.138.153.219, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132986834 (127M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set.zip’
#
# /content/drive/MyDr 100%[===================>] 126.83M  44.3MB/s    in 2.9s
#
# 2026-03-23 17:51:37 (44.3 MB/s) - ‘/content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set.zip’ saved [132986834/132986834]

# %%
# !unzip /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set.zip -d /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set
# Out:
# Archive:  /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set.zip
#    creating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/100_HC.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/101_HC.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/102_2HC.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/103_HC.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/104_HC.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/105_3HC.png
#   inflating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/test_set/test_set/106_HC.png
# ...

# %%
# !unzip /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set.zip -d /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set
# Out:
# Archive:  /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set.zip
#    creating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/100_2HC.png
#   inflating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/100_2HC_Annotation.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/101_HC.png
#   inflating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/101_HC_Annotation.png
#  extracting: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/102_2HC.png
#   inflating: /content/drive/MyDrive/SHAD/project/fetal_head_circumference/training_set/training_set/102_2HC_Annotation.png
# ...

# %%
# !wget https://zenodo.org/records/14597550/files/FOCUS-dataset.zip -O /content/drive/MyDrive/SHAD/project/FOCUS-dataset.zip
# Out:
# --2026-03-23 18:04:13--  https://zenodo.org/records/14597550/files/FOCUS-dataset.zip
# Resolving zenodo.org (zenodo.org)... 188.185.43.153, 188.185.48.75, 137.138.153.219, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61152682 (58M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/FOCUS-dataset.zip’
#
# /content/drive/MyDr 100%[===================>]  58.32M  36.1MB/s    in 1.6s
#
# 2026-03-23 18:04:15 (36.1 MB/s) - ‘/content/drive/MyDrive/SHAD/project/FOCUS-dataset.zip’ saved [61152682/61152682]

# %%
# !unzip /content/drive/MyDrive/SHAD/project/FOCUS-dataset.zip -d /content/drive/MyDrive/SHAD/project/focus
# Out:
# Archive:  /content/drive/MyDrive/SHAD/project/FOCUS-dataset.zip
#    creating: /content/drive/MyDrive/SHAD/project/focus/testing/
#    creating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/001.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/002.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/003.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/004.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/005.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/006.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/007.txt
#   inflating: /content/drive/MyDrive/SHAD/project/focus/testing/annfiles_ellipse/008.txt
# ...

# %%
# !wget https://zenodo.org/records/11005384/files/acouslic-ai-train-set.zip  -O /content/drive/MyDrive/SHAD/project/acouslic-ai
# Out:
# --2026-03-23 20:12:16--  https://zenodo.org/records/11005384/files/acouslic-ai-train-set.zip
# Resolving zenodo.org (zenodo.org)... 137.138.52.235, 188.185.48.75, 188.184.98.114, ...
# Connecting to zenodo.org (zenodo.org)|137.138.52.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37942594974 (35G) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/SHAD/project/acouslic-ai’
#
# rive/SHAD/project/a  84%[===============>    ]  29.91G  52.5MB/s    eta 2m 4s

# %%
# !unzip /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset.zip -d /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset
# Out:
# Archive:  /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset.zip
#    creating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P028_IMG1.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P0156_IMG1.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P0161_IMG1.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P059_IMG1.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P0161_IMG3.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P0161_IMG6.npy
#   inflating: /content/drive/MyDrive/SHAD/project/FetalAbdominalSegmentationDataset/ARRAY_FORMAT/P0161_IMG7.npy
# ...
